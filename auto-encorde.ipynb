# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/jane-street-market-prediction/example_sample_submission.csv
# /kaggle/input/jane-street-market-prediction/features.csv
# /kaggle/input/jane-street-market-prediction/example_test.csv
# /kaggle/input/jane-street-market-prediction/train.csv
# /kaggle/input/jane-street-market-prediction/janestreet/competition.cpython-37m-x86_64-linux-gnu.so
# /kaggle/input/jane-street-market-prediction/janestreet/__init__.py
# /kaggle/input/jane-model-weight/model_42_3_finetune.hdf5
# /kaggle/input/jane-model-weight/encoder.hdf5
# /kaggle/input/jane-model-weight/model_42_0.hdf5
# /kaggle/input/jane-model-weight/model_42_0_finetune.hdf5
# /kaggle/input/jane-model-weight/model_42_4_finetune.hdf5
# /kaggle/input/jane-model-weight/model_42_3.hdf5
# /kaggle/input/jane-model-weight/model_42_2.hdf5
# /kaggle/input/jane-model-weight/model_42_1_finetune.hdf5
# /kaggle/input/jane-model-weight/model_42_1.hdf5
# /kaggle/input/jane-model-weight/model_42_2_finetune.hdf5
# /kaggle/input/jane-model-weight/best_hp_42.pkl
# /kaggle/input/jane-model-weight/model_42_4.hdf5

# %% [markdown]
# ## Encoder + MLP
# The idea of using an encoder is the denoise the data. After many attempts at using a unsupervised autoencoder, the choice landed on a bottleneck encoder as this will preserve the intra-feature relations.

# %%
from tensorflow.keras.layers import Input, Dense, BatchNormalization, Dropout, Concatenate, Lambda, GaussianNoise, Activation
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers.experimental.preprocessing import Normalization
import tensorflow as tf

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler,MinMaxScaler

from tqdm import tqdm
from random import choices

import kerastuner as kt

# %%
# seed set
SEED = 2021

tf.random.set_seed(SEED)
np.random.seed(SEED)

# %%
TRAINING = True
USE_FINETUNE = False 
FOLDS = 4

# %% [markdown]
# ## PurgedGroupTimeSeriesSplit
# Click the code button to see.

# %%
import numpy as np
from sklearn.model_selection import KFold
from sklearn.model_selection._split import _BaseKFold, indexable, _num_samples
from sklearn.utils.validation import _deprecate_positional_args

# modified code for group gaps; source
# https://github.com/getgaurav2/scikit-learn/blob/d4a3af5cc9da3a76f0266932644b884c99724c57/sklearn/model_selection/_split.py#L2243
class PurgedGroupTimeSeriesSplit(_BaseKFold):
    """Time Series cross-validator variant with non-overlapping groups.
    Allows for a gap in groups to avoid potentially leaking info from
    train into test if the model has windowed or lag features.
    Provides train/test indices to split time series data samples
    that are observed at fixed time intervals according to a
    third-party provided group.
    In each split, test indices must be higher than before, and thus shuffling
    in cross validator is inappropriate.
    This cross-validation object is a variation of :class:`KFold`.
    In the kth split, it returns first k folds as train set and the
    (k+1)th fold as test set.
    The same group will not appear in two different folds (the number of
    distinct groups has to be at least equal to the number of folds).
    Note that unlike standard cross-validation methods, successive
    training sets are supersets of those that come before them.
    Read more in the :ref:`User Guide <cross_validation>`.
    Parameters
    ----------
    n_splits : int, default=5
        Number of splits. Must be at least 2.
    max_train_group_size : int, default=Inf
        Maximum group size for a single training set.
    group_gap : int, default=None
        Gap between train and test
    max_test_group_size : int, default=Inf
        We discard this number of groups from the end of each train split
    """
    @_deprecate_positional_args
    def __init__(self,
                 n_splits=5,
                 *,
                 max_train_group_size=np.inf,
                 max_test_group_size=np.inf,
                 group_gap=None,
                 verbose=False
                 ):
        super().__init__(n_splits, shuffle=False, random_state=None)
        self.max_train_group_size = max_train_group_size
        self.group_gap = group_gap
        self.max_test_group_size = max_test_group_size
        self.verbose = verbose

    def split(self, X, y=None, groups=None):
        """Generate indices to split data into training and test set.
        Parameters
        ----------
        X : array-like of shape (n_samples, n_features)
            Training data, where n_samples is the number of samples
            and n_features is the number of features.
        y : array-like of shape (n_samples,)
            Always ignored, exists for compatibility.
        groups : array-like of shape (n_samples,)
            Group labels for the samples used while splitting the dataset into
            train/test set.
        Yields
        ------
        train : ndarray
            The training set indices for that split.
        test : ndarray
            The testing set indices for that split.
        """
        if groups is None:
            raise ValueError(
                "The 'groups' parameter should not be None")
        X, y, groups = indexable(X, y, groups)
        n_samples = _num_samples(X)
        n_splits = self.n_splits
        group_gap = self.group_gap
        max_test_group_size = self.max_test_group_size
        max_train_group_size = self.max_train_group_size
        n_folds = n_splits + 1
        group_dict = {}
        u, ind = np.unique(groups, return_index=True)
        unique_groups = u[np.argsort(ind)]
        n_samples = _num_samples(X)
        n_groups = _num_samples(unique_groups)
        for idx in np.arange(n_samples):
            if (groups[idx] in group_dict):
                group_dict[groups[idx]].append(idx)
            else:
                group_dict[groups[idx]] = [idx]
        if n_folds > n_groups:
            raise ValueError(
                ("Cannot have number of folds={0} greater than"
                 " the number of groups={1}").format(n_folds,
                                                     n_groups))

        group_test_size = min(n_groups // n_folds, max_test_group_size)
        group_test_starts = range(n_groups - n_splits * group_test_size,
                                  n_groups, group_test_size)
        for group_test_start in group_test_starts:
            train_array = []
            test_array = []

            group_st = max(0, group_test_start - group_gap - max_train_group_size)
            for train_group_idx in unique_groups[group_st:(group_test_start - group_gap)]:
                train_array_tmp = group_dict[train_group_idx]
                
                train_array = np.sort(np.unique(
                                      np.concatenate((train_array,
                                                      train_array_tmp)),
                                      axis=None), axis=None)

            train_end = train_array.size
 
            for test_group_idx in unique_groups[group_test_start:
                                                group_test_start +
                                                group_test_size]:
                test_array_tmp = group_dict[test_group_idx]
                test_array = np.sort(np.unique(
                                              np.concatenate((test_array,
                                                              test_array_tmp)),
                                     axis=None), axis=None)

            test_array  = test_array[group_gap:]
            
            
            if self.verbose > 0:
                    pass
                    
            yield [int(i) for i in train_array], [int(i) for i in test_array]

# %%
class CVTuner(kt.engine.tuner.Tuner):
    def run_trial(self, trial, X, y, splits, batch_size=32, epochs=1,callbacks=None):
        val_losses = []
        for train_indices, test_indices in splits:
            X_train, X_test = [x[train_indices] for x in X], [x[test_indices] for x in X]
            y_train, y_test = [a[train_indices] for a in y], [a[test_indices] for a in y]
            if len(X_train) < 2:
                X_train = X_train[0]
                X_test = X_test[0]
            if len(y_train) < 2:
                y_train = y_train[0]
                y_test = y_test[0]
            
            model = self.hypermodel.build(trial.hyperparameters)
            hist = model.fit(X_train,y_train,
                      validation_data=(X_test,y_test),
                      epochs=epochs,
                        batch_size=batch_size,
                      callbacks=callbacks)
            
            val_losses.append([hist.history[k][-1] for k in hist.history])
        val_losses = np.asarray(val_losses)
        self.oracle.update_trial(trial.trial_id, {k:np.mean(val_losses[:,i]) for i,k in enumerate(hist.history.keys())})
        self.save_model(trial.trial_id, model)

# %% [markdown]
# ### Loading the training data

# %%
print('Reading...')
train = pd.read_csv('../input/jane-street-market-prediction/train.csv')

print('Completed')


print('Pre-processing...')
train = train.query('date > 85').reset_index(drop = True) 
train = train.astype({c: np.float32 for c in train.select_dtypes(include='float64').columns}) #limit memory use

train.fillna(train.mean(),inplace=True)
train = train.query('weight > 0').reset_index(drop = True)

#train['action'] =  (  (train['resp_1'] > 0 ) & (train['resp_2'] > 0 ) & (train['resp_3'] > 0 ) & (train['resp_4'] > 0 ) &  (train['resp'] > 0 )   ).astype('int')

pre_scaler = MinMaxScaler()
resp = train[['resp_1','resp_2','resp_3','resp_4','resp']]
resp[['resp_1','resp_2','resp_3','resp_4','resp']] = pre_scaler.fit_transform(resp[['resp_1','resp_2','resp_3','resp_4','resp']])

# action = 1とするresp(=featureとの関係性)を学習させるターゲットとする
train['action'] = ((resp['resp']>0.551)&(resp['resp_1']>0.501)&(resp['resp_2']>0.50)&(resp['resp_3']>0.554)&(resp['resp_4']>0.55)).astype('int')
features = [c for c in train.columns if 'feature' in c]

resp_cols = [('resp_1',0.501),('resp_2',0.50),('resp_3',0.554),('resp',0.551),('resp_4',0.55)]

X = train[features]
y = np.stack([(resp[c] > p).astype('int') for c,p in resp_cols]).T #Multitarget resp.. >0 => 1 convert

scaler = MinMaxScaler()
X = scaler.fit_transform(X)

f_mean = np.mean(train[features[1:]].values,axis=0)

print('Completed')
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:3076: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.iloc._setitem_with_indexer((slice(None), indexer), value)
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:3041: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_array(key, value)

# %%
y
# Out:
# array([[1, 1, 1, 0, 0],
#        [1, 1, 1, 0, 0],
#        [1, 1, 1, 1, 0],
#        ...,
#        [1, 1, 1, 0, 0],
#        [1, 1, 1, 0, 0],
#        [1, 1, 1, 0, 0]])

# %% [markdown]
# ### Creating the autoencoder.
# The autoencoder should aid in denoising the data. Based on [this](https://www.semanticscholar.org/paper/Deep-Bottleneck-Classifiers-in-Supervised-Dimension-Parviainen/fb86483f7573f6430fe4597432b0cd3e34b16e43) paper.

# %%
def create_autoencoder(input_dim,output_dim,noise=0.05):
    i = Input(input_dim)
    encoded = BatchNormalization()(i)
    encoded = GaussianNoise(noise)(encoded)
    encoded = Dense(input_dim,activation='relu')(encoded) # 64,128
    decoded = Dropout(0.20)(encoded)
    decoded = Dense(input_dim,name='decoded')(decoded)
    x = Dense(256,activation='relu')(decoded)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    x = Dense(128,activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    x = Dense(output_dim,activation='sigmoid',name='label_output')(x)
    
    encoder = Model(inputs=i,outputs=encoded)
    autoencoder = Model(inputs=i,outputs=[decoded,x])
    
    autoencoder.compile(optimizer=Adam(0.01),loss={'decoded':'mse','label_output':'binary_crossentropy'})
    
    return autoencoder, encoder

# %% [markdown]
# ### Creating the MLP.

# %%
def create_model(hp,input_dim,output_dim,encoder):
    
    inputs = Input(input_dim)
    
    x = encoder(inputs)
    x = Concatenate()([x,inputs]) #use both raw and encoded features
    x = BatchNormalization()(x)
    x = Dropout(hp.Float('init_dropout',0.0,0.5))(x)
    
    for i in range(hp.Int('num_layers',1,3)):
        x = Dense(hp.Int('num_units_{i}',64,256))(x)
        x = BatchNormalization()(x)
        x = Lambda(tf.keras.activations.swish)(x)
        x = Dropout(hp.Float(f'dropout_{i}',0.0,0.5))(x)
        
    x = Dense(output_dim,activation='sigmoid')(x)
    
    model = Model(inputs=inputs, outputs=x)
    model.compile(optimizer=Adam(hp.Float('lr',0.00001,0.1,default=0.001)),
                  loss=BinaryCrossentropy(label_smoothing=hp.Float('label_smoothing',0.0,0.1)),
                  metrics=[tf.keras.metrics.AUC(name = 'auc')])
    
    return model

# %% [markdown]
# ### Defining and training the autoencoder.
# We add gaussian noise with mean and std from training data. After training we lock the layers in the encoder from further training.

# %%
autoencoder, encoder = create_autoencoder(X.shape[-1],y.shape[-1],noise=0.1)

if TRAINING:
    autoencoder.fit(X,(X,y),
                    epochs=1000,
                    batch_size=4096, 
                    validation_split=0.1,
                    callbacks=[EarlyStopping('val_loss',patience=10,restore_best_weights=True)])
    encoder.save_weights('./encoder.hdf5')
    
else:
    encoder.load_weights('../input/jane-model-weight/encoder.hdf5')
    
encoder.trainable = False
# Out:
# Epoch 1/1000
# 346/346 [==============================] - 3s 10ms/step - loss: 0.3561 - decoded_loss: 0.0094 - label_output_loss: 0.3468 - val_loss: 0.3448 - val_decoded_loss: 0.0023 - val_label_output_loss: 0.3425
# Epoch 2/1000
# 346/346 [==============================] - 3s 9ms/step - loss: 0.3332 - decoded_loss: 0.0025 - label_output_loss: 0.3307 - val_loss: 0.3339 - val_decoded_loss: 0.0022 - val_label_output_loss: 0.3317
# Epoch 3/1000
# 346/346 [==============================] - 3s 9ms/step - loss: 0.3327 - decoded_loss: 0.0023 - label_output_loss: 0.3303 - val_loss: 0.3788 - val_decoded_loss: 0.0016 - val_label_output_loss: 0.3772
# Epoch 4/1000
# 346/346 [==============================] - 3s 9ms/step - loss: 0.3324 - decoded_loss: 0.0022 - label_output_loss: 0.3301 - val_loss: 0.3358 - val_decoded_loss: 0.0014 - val_label_output_loss: 0.3343
# Epoch 5/1000
# 346/346 [==============================] - 3s 9ms/step - loss: 0.3318 - decoded_loss: 0.0021 - label_output_loss: 0.3297 - val_loss: 0.3317 - val_decoded_loss: 0.0012 - val_label_output_loss: 0.3305
# Epoch 6/1000
# 346/346 [==============================] - 3s 10ms/step - loss: 0.3319 - decoded_loss: 0.0022 - label_output_loss: 0.3297 - val_loss: 0.3339 - val_decoded_loss: 0.0015 - val_label_output_loss: 0.3324
# Epoch 7/1000
# 346/346 [==============================] - 4s 12ms/step - loss: 0.3321 - decoded_loss: 0.0022 - label_output_loss: 0.3299 - val_loss: 0.3388 - val_decoded_loss: 0.0015 - val_label_output_loss: 0.3373
# Epoch 8/1000
# 346/346 [==============================] - 3s 9ms/step - loss: 0.3322 - decoded_loss: 0.0023 - label_output_loss: 0.3299 - val_loss: 0.3316 - val_decoded_loss: 0.0015 - val_label_output_loss: 0.3301
# Epoch 9/1000
# 346/346 [==============================] - 3s 9ms/step - loss: 0.3326 - decoded_loss: 0.0025 - label_output_loss: 0.3302 - val_loss: 0.3452 - val_decoded_loss: 0.0017 - val_label_output_loss: 0.3435
# Epoch 10/1000
# 346/346 [==============================] - 3s 10ms/step - loss: 0.3340 - decoded_loss: 0.0030 - label_output_loss: 0.3310 - val_loss: 0.3344 - val_decoded_loss: 0.0022 - val_label_output_loss: 0.3321
# Epoch 11/1000
# 346/346 [==============================] - 3s 9ms/step - loss: 0.3337 - decoded_loss: 0.0029 - label_output_loss: 0.3308 - val_loss: 0.3434 - val_decoded_loss: 0.0020 - val_label_output_loss: 0.3413
# Epoch 12/1000
# 346/346 [==============================] - 3s 9ms/step - loss: 0.3334 - decoded_loss: 0.0029 - label_output_loss: 0.3306 - val_loss: 0.3360 - val_decoded_loss: 0.0025 - val_label_output_loss: 0.3335
# Epoch 13/1000
# 346/346 [==============================] - 3s 9ms/step - loss: 0.3334 - decoded_loss: 0.0029 - label_output_loss: 0.3305 - val_loss: 0.3490 - val_decoded_loss: 0.0022 - val_label_output_loss: 0.3468
# Epoch 14/1000
# 346/346 [==============================] - 3s 9ms/step - loss: 0.3355 - decoded_loss: 0.0039 - label_output_loss: 0.3316 - val_loss: 0.3448 - val_decoded_loss: 0.0023 - val_label_output_loss: 0.3424
# Epoch 15/1000
# 346/346 [==============================] - 3s 9ms/step - loss: 0.3341 - decoded_loss: 0.0032 - label_output_loss: 0.3310 - val_loss: 0.3398 - val_decoded_loss: 0.0024 - val_label_output_loss: 0.3374
# Epoch 16/1000
# 346/346 [==============================] - 3s 9ms/step - loss: 0.3338 - decoded_loss: 0.0031 - label_output_loss: 0.3307 - val_loss: 0.3390 - val_decoded_loss: 0.0026 - val_label_output_loss: 0.3363
# Epoch 17/1000
# 346/346 [==============================] - 4s 11ms/step - loss: 0.3337 - decoded_loss: 0.0031 - label_output_loss: 0.3306 - val_loss: 0.3346 - val_decoded_loss: 0.0025 - val_label_output_loss: 0.3321
# Epoch 18/1000
# 346/346 [==============================] - 3s 9ms/step - loss: 0.3335 - decoded_loss: 0.0031 - label_output_loss: 0.3304 - val_loss: 0.3765 - val_decoded_loss: 0.0023 - val_label_output_loss: 0.3742

# %% [markdown]
# ### Running CV
# Following [this notebook](https://www.kaggle.com/gogo827jz/jane-street-ffill-xgboost-purgedtimeseriescv) which use 5 PurgedGroupTimeSeriesSplit split on the dates in the training data.
#
# We add the locked encoder as the first layer of the MLP. This seems to help in speeding up the submission rather than first predicting using the encoder then using the MLP.

# %% [markdown]
# We use a Baysian Optimizer to find the optimal HPs for out model. 20 trials take about 2 hours on GPU.

# %%
model_fn = lambda hp: create_model(hp,X.shape[-1],y.shape[-1],encoder)

tuner = CVTuner(
        hypermodel=model_fn,
        oracle=kt.oracles.BayesianOptimization(
        objective= kt.Objective('val_auc', direction='max'),
        num_initial_points=4,
        max_trials=10))

if TRAINING:
    gkf = PurgedGroupTimeSeriesSplit(n_splits = FOLDS, group_gap=20)
    splits = list(gkf.split(y, groups=train['date'].values))
    tuner.search((X,),(y,),splits=splits,batch_size=4096,epochs=100,callbacks=[EarlyStopping('val_auc', mode='max',patience=2)])
    hp  = tuner.get_best_hyperparameters(1)[0]
    pd.to_pickle(hp,f'./best_hp_{SEED}.pkl')
    
    for fold, (train_indices, test_indices) in enumerate(splits):
        model = model_fn(hp)
        X_train, X_test = X[train_indices], X[test_indices]
        y_train, y_test = y[train_indices], y[test_indices]
        
        model.fit(X_train,y_train,
                  validation_data=(X_test,y_test),
                  epochs=100,
                  batch_size=4096,
                  callbacks=[EarlyStopping('val_auc',mode='max',patience=10,restore_best_weights=True)]
                 )
        
        model.save_weights(f'./jane-model-weight/model_{SEED}_{fold}.hdf5')
        model.compile(Adam(hp.get('lr')/100),loss='binary_crossentropy')
        model.fit(X_test,y_test,epochs=3,batch_size=4096)
        model.save_weights(f'./jane-model-weight/model_{SEED}_{fold}_finetune.hdf5')
        
    tuner.results_summary()
    
else:
    models = []
    hp = pd.read_pickle(f'../input/jane-model-weight/best_hp_{SEED}.pkl')
    
    for f in range(FOLDS):
        model = model_fn(hp)
        
        if USE_FINETUNE:
            model.load_weights(f'../input/jane-model-weight/model_{SEED}_{f}_finetune.hdf5')
            
        else:
            model.load_weights(f'../input/jane-model-weight/model_{SEED}_{f}.hdf5')
        models.append(model)

# %% [markdown]
# ## Submission

# %%
if not TRAINING:
    
    f = np.median
    
    models = models[-2:]
    import janestreet
    env = janestreet.make_env()
    th = 0.55
    
    for (test_df, pred_df) in tqdm(env.iter_test()):
        
        if test_df['weight'].item() > 0:
            x_tt = test_df.loc[:, features]
            x_tt = scaler.transform(x_tt)
            
            if np.isnan(x_tt[:, 1:].sum()):
                x_tt[:, 1:] = np.nan_to_num(x_tt[:, 1:]) + np.isnan(x_tt[:, 1:]) * f_mean
                
            pred = np.mean([model(x_tt, training = False).numpy() for model in models],axis=0)
            pred = f(pred)
            pred_df.action = np.where(pred >= th, 1, 0).astype(int)
            
        else:
            pred_df.action = 0
        env.predict(pred_df)
